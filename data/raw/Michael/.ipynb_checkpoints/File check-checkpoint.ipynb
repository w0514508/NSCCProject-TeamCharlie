# %% [markdown]
# ## GHG Emissions in Canada

# %%
#LOAD THE RAW DATA

import pandas as pd

df = pd.read_csv("GHG Provinces & Territories Raw Data.csv")


df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17914 entries, 0 to 17913
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   REF_DATE       17914 non-null  int64
#  1   GEO            17914 non-null  str
#  2   DGUID          17914 non-null  str
#  3   Sector         17914 non-null  str
#  4   UOM            17914 non-null  str
#  5   UOM_ID         17914 non-null  int64
#  6   SCALAR_FACTOR  17914 non-null  str
#  7   SCALAR_ID      17914 non-null  int64
#  8   VECTOR         17914 non-null  str
#  9   COORDINATE     17914 non-null  float64
#  10  VALUE          14225 non-null  float64
#  11  STATUS         3689 non-null   str
#  12  SYMBOL         0 non-null      float64
#  13  TERMINATED     0 non-null      float64
#  14  DECIMALS       17914 non-null  int64
# dtypes: float64(4), int64(4), str(7)
# memory usage: 2.1 MB

# %%
df.head()
# Out:
#    REF_DATE                        GEO        DGUID  \
# 0      2013  Newfoundland and Labrador  2021A000210
# 1      2014  Newfoundland and Labrador  2021A000210
# 2      2015  Newfoundland and Labrador  2021A000210
# 3      2016  Newfoundland and Labrador  2021A000210
# 4      2017  Newfoundland and Labrador  2021A000210
#
#                                  Sector         UOM  UOM_ID SCALAR_FACTOR  \
# 0  Crop and animal production [BS11A00]  Kilotonnes     198         units
# 1  Crop and animal production [BS11A00]  Kilotonnes     198         units
# 2  Crop and animal production [BS11A00]  Kilotonnes     198         units
# 3  Crop and animal production [BS11A00]  Kilotonnes     198         units
# 4  Crop and animal production [BS11A00]  Kilotonnes     198         units
#
#    SCALAR_ID       VECTOR  COORDINATE  VALUE STATUS  SYMBOL  TERMINATED  \
# 0          0  v1013973304         2.3  114.0    NaN     NaN         NaN
# ...

# %%
#CHECK WHAT ALL THE COLUMNS TO DETERMINE USAGE
print(df.columns)
print("Shape of dataset:", df.shape)
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Sector', 'UOM', 'UOM_ID', 'SCALAR_FACTOR',
#        'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL',
#        'TERMINATED', 'DECIMALS'],
#       dtype='str')
# Shape of dataset: (17914, 15)

# %%
df["Sector"].nunique()
# Out:
# 133

# %%
#KEEP ONLY WHAT IS NEEDED
df = df[["REF_DATE", "GEO", "VALUE", "Sector"]]

# %%
print(df.columns)
# Out:
# Index(['REF_DATE', 'GEO', 'VALUE', 'Sector'], dtype='str')

# %%
#RENAME COLUMNS (MAKE IT CLEAN)
df.columns = ["Year", "Provinces", "Emissions", "Sectors"]

# %%
df.head()
# Out:
#    Year                  Provinces  Emissions  \
# 0  2013  Newfoundland and Labrador      114.0
# 1  2014  Newfoundland and Labrador        NaN
# 2  2015  Newfoundland and Labrador        NaN
# 3  2016  Newfoundland and Labrador        NaN
# 4  2017  Newfoundland and Labrador        NaN
#
#                                 Sectors
# 0  Crop and animal production [BS11A00]
# 1  Crop and animal production [BS11A00]
# 2  Crop and animal production [BS11A00]
# 3  Crop and animal production [BS11A00]
# 4  Crop and animal production [BS11A00]

# %%
print(df.columns)
# Out:
# Index(['Year', 'Provinces', 'Emissions', 'Sectors'], dtype='object')

# %%
df.isna().sum()
# Out:
# Year            0
# Provinces       0
# Emissions    3689
# Sectors         0
# dtype: int64

# %%
#REMOVE NULLS
df = df.dropna()

# %%
#FIX DATA TYPES
df["Year"] = pd.to_datetime(df["Year"], format="%Y")
df["Emissions"] = df["Emissions"].astype(float)

# %%
latest_year = df["Year"].max()
df = df[df["Year"] >= latest_year - pd.DateOffset(years=10)]

# %%
#REMOVE TOTAL / DUPLICATES
df = df[df["Provinces"] != "Canada"]

# %%
#CREATE CLEAN DATASETS FOR PROVINCES (FOR MAIN CHARTS)

df_province = df.groupby(["Year", "Provinces"])["Emissions"].sum().reset_index()

df_province.to_csv("ghg_province_clean.csv", index=False)

# %%
# CREATE CLEAN DATASETS FOR SECTOR DATA (NS ONLY)
df_sector_ns = df[df["Provinces"] == "Nova Scotia"]

df_sector_ns = df_sector_ns.groupby(["Year", "Sectors"])["Emissions"].sum().reset_index()

df_sector_ns.to_csv("ghg_sector_ns_clean.csv", index=False)

# %%
from IPython.display import FileLink

FileLink("ghg_province_clean.csv")
# Out:
# C:\Users\USER-PC\ghg_province_clean.csv

# %%
print(df.columns)
# Out:
# Index(['Year', 'Provinces', 'Emissions', 'Sectors'], dtype='object')
