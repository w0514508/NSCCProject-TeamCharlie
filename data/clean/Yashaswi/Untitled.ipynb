# %%
import pandas as pd

df = pd.read_csv("../Yashaswi/Atlantic_Climate.csv", 
                    dtype={"Climate ID": "string"},
                    low_memory=False
)

# %%
df.head()
# Out:
#    Longitude (x)  Latitude (y)  Station Name Climate ID   Date/Time  Year  \
# 0         -64.51         44.83  AALDERSVILLE    8204020  2021-01-01  2021
# 1         -64.51         44.83  AALDERSVILLE    8204020  2021-01-02  2021
# 2         -64.51         44.83  AALDERSVILLE    8204020  2021-01-03  2021
# 3         -64.51         44.83  AALDERSVILLE    8204020  2021-01-04  2021
# 4         -64.51         44.83  AALDERSVILLE    8204020  2021-01-05  2021
#
#    Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  Heat Deg Days (°C)  \
# 0            NaN            NaN             NaN                 NaN
# 1            NaN            NaN             NaN                 NaN
# 2            NaN            NaN             NaN                 NaN
# 3            NaN            NaN             NaN                 NaN
# 4            NaN            NaN             NaN                 NaN
#
#    Cool Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  Total Precip (mm)  \
# ...
