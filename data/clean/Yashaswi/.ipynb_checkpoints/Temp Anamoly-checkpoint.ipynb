# %% [markdown]
# # Temperature anomaly calculation vs. 30-year baseline

# %%
import pandas as pd

df = pd.read_csv("../../../data/clean/Yashaswi/Final_Clean/temp_clean_Daily.csv", 
                    dtype={"Climate ID": "string"},
                    low_memory=False
)
stations = pd.read_csv("../../clean/Yashaswi/Final_Clean/dim_station_clean.csv")

df["Date"] = pd.to_datetime(df["Date"])
df["Year"]  = df["Date"].dt.year
df["Month"] = df["Date"].dt.month
df["Day"]   = df["Date"].dt.day

# %%
df.columns
# Out:
# Index(['Climate ID', 'Date', 'Max Temp (°C)', 'Min Temp (°C)',
#        'Mean Temp (°C)', 'Heat Deg Days (°C)', 'Cool Deg Days (°C)', 'Year',
#        'Month', 'Day'],
#       dtype='str')

# %%
df.head()
# Out:
#   Climate ID       Date  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0    8204020 2021-09-11           18.7            8.7            13.7
# 1    8204020 2021-09-12           22.4            9.8            16.1
# 2    8204020 2021-09-13           20.8           11.0            15.9
# 3    8204020 2021-09-14           17.2            6.9            12.1
# 4    8204020 2021-09-15           20.2            5.7            13.0
#
#    Heat Deg Days (°C)  Cool Deg Days (°C)  Year  Month  Day
# 0                 4.3                 0.0  2021      9   11
# 1                 1.9                 0.0  2021      9   12
# 2                 2.1                 0.0  2021      9   13
# 3                 5.9                 0.0  2021      9   14
# 4                 5.0                 0.0  2021      9   15

# %%
stations.columns
# Out:
# Index(['Longitude (x)', 'Latitude (y)', 'Station Name', 'Climate ID',
#        'Province'],
#       dtype='str')

# %%
df = df.rename(columns={"Climate ID": "station_id"})
stations = stations.rename(columns={"Climate ID": "station_id"})

# %%
df = df.merge(
    stations,
    on="station_id",
    how="left"
)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 818993 entries, 0 to 818992
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   station_id          818993 non-null  object
#  1   Date                818993 non-null  datetime64[us]
#  2   Max Temp (°C)       814288 non-null  float64
#  3   Min Temp (°C)       816921 non-null  float64
#  4   Mean Temp (°C)      818993 non-null  float64
#  5   Heat Deg Days (°C)  812218 non-null  float64
#  6   Cool Deg Days (°C)  812218 non-null  float64
#  7   Year                818993 non-null  int32
#  8   Month               818993 non-null  int32
#  9   Day                 818993 non-null  int32
#  10  Longitude (x)       818993 non-null  float64
#  11  Latitude (y)        818993 non-null  float64
#  12  Station Name        818993 non-null  str
#  13  Province            818993 non-null  str
# dtypes: datetime64[us](1), float64(7), int32(3), object(1), str(2)
# memory usage: 102.9+ MB

# %% [markdown]
# ## Check: Inspect temperature on 1st Jan each year

# %%
df.loc[
    (df["station_id"] == "8100300") &
    (df["Month"] == 1) &
    (df["Day"] == 1),
    ["Year", "Mean Temp (°C)"]
]
# Out:
#        Year  Mean Temp (°C)
# 10755  1995           -11.0
# 11120  1996           -21.8
# 11486  1997           -17.0
# 11851  1998           -16.3
# 12216  1999           -26.5
# 12581  2000           -11.3
# 12947  2001             0.0
# 13523  2004            -7.5
# 13889  2005             3.0
# 14131  2008            -9.3
# 14497  2009           -16.5
# 14856  2010            -7.0
# 15208  2011             2.8
# 15560  2012             0.0
# 15907  2013           -13.3
# 16259  2014           -22.0
# 16877  2016            -3.0
# 17309  2018           -18.8
# 17667  2019            -6.0
# 18023  2020            -2.5
# 18375  2021            -8.8
# 18732  2022             0.3
# 19097  2023             2.3
# 19428  2024            -6.8
# 19759  2025             0.5

# %% [markdown]
# ## Temperature Anomaly  (30‑Year Baseline)

# %%
BASELINE_START = 1995
BASELINE_END   = 2025

df_baseline_src = df[
    (df["Year"] >= BASELINE_START) &
    (df["Year"] <= BASELINE_END)
]

# %% [markdown]
# ## Compute daily climatology baseline

# %%
baseline = (
    df_baseline_src
    .groupby(["station_id", "Month", "Day"], as_index=False)
    ["Mean Temp (°C)"]
    .mean()
    .rename(columns={
        "Mean Temp (°C)": "Baseline Mean Temp (°C)"
    })
)
baseline.head(3)
# Out:
#   station_id  Month  Day  Baseline Mean Temp (°C)
# 0    8100300      1    1                -8.660000
# 1    8100300      1    2                -9.565385
# 2    8100300      1    3               -10.623077

# %% [markdown]
# ## Merge baseline to full dataset

# %%
# Drop existing baseline/anomaly columns if they exist
df = df.drop(
    columns=["Baseline Mean Temp (°C)", "Temp Anomaly (°C)"],
    errors="ignore"
)

df = df.merge(
    baseline,
    on=["station_id", "Month", "Day"],
    how="left"
)
df.loc[
    (df["station_id"] == "8100300") &
    (df["Month"] == 1) &
    (df["Day"] == 1),
    ["Year", "Mean Temp (°C)","Baseline Mean Temp (°C)"]
]
# Out:
#        Year  Mean Temp (°C)  Baseline Mean Temp (°C)
# 10755  1995           -11.0                    -8.66
# 11120  1996           -21.8                    -8.66
# 11486  1997           -17.0                    -8.66
# 11851  1998           -16.3                    -8.66
# 12216  1999           -26.5                    -8.66
# 12581  2000           -11.3                    -8.66
# 12947  2001             0.0                    -8.66
# 13523  2004            -7.5                    -8.66
# 13889  2005             3.0                    -8.66
# 14131  2008            -9.3                    -8.66
# 14497  2009           -16.5                    -8.66
# 14856  2010            -7.0                    -8.66
# 15208  2011             2.8                    -8.66
# 15560  2012             0.0                    -8.66
# 15907  2013           -13.3                    -8.66
# 16259  2014           -22.0                    -8.66
# 16877  2016            -3.0                    -8.66
# 17309  2018           -18.8                    -8.66
# 17667  2019            -6.0                    -8.66
# 18023  2020            -2.5                    -8.66
# 18375  2021            -8.8                    -8.66
# 18732  2022             0.3                    -8.66
# 19097  2023             2.3                    -8.66
# 19428  2024            -6.8                    -8.66
# 19759  2025             0.5                    -8.66

# %% [markdown]
# ## Calculate temperature anomaly

# %%
df["Temp Anomaly (°C)"] = (
    df["Mean Temp (°C)"] -
    df["Baseline Mean Temp (°C)"]
)

# %% [markdown]
# ## Quality‑assurance checks

# %%
print("Missing baseline (%):",
      df["Baseline Mean Temp (°C)"].isna().mean() * 100)
# Out:
# Missing baseline (%): 0.0

# %%
df["Temp Anomaly (°C)"].describe()
# Out:
# count    8.189930e+05
# mean    -1.388130e-18
# std      3.744718e+00
# min     -2.942500e+01
# 25%     -2.327586e+00
# 50%     -7.200000e-02
# 75%      2.281818e+00
# max      2.127500e+01
# Name: Temp Anomaly (°C), dtype: float64

# %%
df.columns
# Out:
# Index(['station_id', 'Date', 'Max Temp (°C)', 'Min Temp (°C)',
#        'Mean Temp (°C)', 'Heat Deg Days (°C)', 'Cool Deg Days (°C)', 'Year',
#        'Month', 'Day', 'Longitude (x)', 'Latitude (y)', 'Station Name',
#        'Province', 'Baseline Mean Temp (°C)', 'Temp Anomaly (°C)'],
#       dtype='str')

# %%
baseline_df = df[[
    "station_id",
    "Month",
    "Day",
    "Baseline Mean Temp (°C)"
]]
baseline_df.head()
# Out:
#   station_id  Month  Day  Baseline Mean Temp (°C)
# 0    8204020      9   11                    16.54
# 1    8204020      9   12                    15.80
# 2    8204020      9   13                    17.14
# 3    8204020      9   14                    15.64
# 4    8204020      9   15                    14.30

# %% [markdown]
# ## ✅ Step 2: Verify uniqueness (VERY important)
# - ✅ Expected result: empty Series
# - ❌ If not empty → conflicting baselines exist and must be resolved

# %%
dup_check = (
    baseline_df
    .groupby(["station_id", "Month", "Day"])["Baseline Mean Temp (°C)"]
    .nunique()
)

dup_check[dup_check > 1]
# Out:
# Series([], Name: Baseline Mean Temp (°C), dtype: int64)

# %%
baseline_df.groupby("station_id").size().describe()
# Out:
# count      136.000000
# mean      6022.007353
# std       3124.680953
# min        244.000000
# 25%       3208.500000
# 50%       5528.500000
# 75%       8321.750000
# max      11320.000000
# dtype: float64

# %%
baseline_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 818993 entries, 0 to 818992
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   station_id               818993 non-null  object
#  1   Month                    818993 non-null  int32
#  2   Day                      818993 non-null  int32
#  3   Baseline Mean Temp (°C)  818993 non-null  float64
# dtypes: float64(1), int32(2), object(1)
# memory usage: 18.7+ MB

# %%
baseline_variation = (
    baseline_df
    .groupby(["station_id", "Month", "Day"])["Baseline Mean Temp (°C)"]
    .nunique()
)
baseline_variation[baseline_variation > 1]
# Out:
# Series([], Name: Baseline Mean Temp (°C), dtype: int64)

# %%
baseline_days_per_station = (
    baseline_df
    .drop_duplicates(["station_id", "Month", "Day"])
    .groupby("station_id")
    .size()
)

baseline_days_per_station.describe()
# Out:
# count    136.000000
# mean     364.485294
# std       15.743304
# min      183.000000
# 25%      366.000000
# 50%      366.000000
# 75%      366.000000
# max      366.000000
# dtype: float64

# %%
baseline_unique = (
    baseline_df
    .groupby(
        ["station_id", "Month", "Day"],
        as_index=False
    )["Baseline Mean Temp (°C)"]
    .first()
)

# %%
baseline_unique.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49570 entries, 0 to 49569
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   station_id               49570 non-null  str
#  1   Month                    49570 non-null  int32
#  2   Day                      49570 non-null  int32
#  3   Baseline Mean Temp (°C)  49570 non-null  float64
# dtypes: float64(1), int32(2), str(1)
# memory usage: 1.5 MB

# %% [markdown]
# ## Export Baseline per station csv

# %%
baseline_unique.to_csv(
    r"../../../data/clean/Yashaswi/Final_Clean/Baseline_per_Station.csv",
    index=False
)

# %% [markdown]
# ## Define and Export Temperature Anomoly table

# %%
bi_anomaly_table = df[
    [
        "station_id",
        "Date",
        "Baseline Mean Temp (°C)",
        "Temp Anomaly (°C)"
    ]
].copy()
bi_anomaly_table["Date"] = pd.to_datetime(bi_anomaly_table["Date"])
bi_anomaly_table["station_id"] = bi_anomaly_table["station_id"].astype(str)

# %%
bi_anomaly_table.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 818993 entries, 0 to 818992
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   station_id               818993 non-null  str
#  1   Date                     818993 non-null  datetime64[us]
#  2   Baseline Mean Temp (°C)  818993 non-null  float64
#  3   Temp Anomaly (°C)        818993 non-null  float64
# dtypes: datetime64[us](1), float64(2), str(1)
# memory usage: 30.5 MB

# %%
# Round only float columns to 4 decimal places
float_cols = bi_anomaly_table.select_dtypes(include="float").columns

bi_anomaly_table[float_cols] = bi_anomaly_table[float_cols].round(4)
float_cols = bi_anomaly_table.select_dtypes(include="float").columns
bi_anomaly_table[float_cols] = bi_anomaly_table[float_cols].astype("float32")

# %%
bi_anomaly_table.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 818993 entries, 0 to 818992
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   station_id               818993 non-null  str
#  1   Date                     818993 non-null  datetime64[us]
#  2   Baseline Mean Temp (°C)  818993 non-null  float32
#  3   Temp Anomaly (°C)        818993 non-null  float32
# dtypes: datetime64[us](1), float32(2), str(1)
# memory usage: 24.2 MB

# %% [markdown]
# ### Check - BI anamoly table

# %%
bi_anomaly_table.groupby(
    ["station_id", bi_anomaly_table["Date"].dt.month, bi_anomaly_table["Date"].dt.day]
)["Baseline Mean Temp (°C)"].nunique().describe()
# Out:
# count    49578.000000
# mean         0.999839
# std          0.012702
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: Baseline Mean Temp (°C), dtype: float64

# %%
bi_anomaly_table["Date"].min(), bi_anomaly_table["Date"].max()
# Out:
# (Timestamp('1995-01-01 00:00:00'), Timestamp('2025-12-31 00:00:00'))

# %%
bi_anomaly_table["Date"].dt.year.describe()
# Out:
# count    818993.000000
# mean       2013.807396
# std           8.259403
# min        1995.000000
# 25%        2008.000000
# 50%        2015.000000
# 75%        2021.000000
# max        2025.000000
# Name: Date, dtype: float64

# %%
bi_anomaly_table["Date"].dt.year.value_counts().sort_index()
# Out:
# Date
# 1995    11402
# 1996    11615
# 1997    11207
# 1998    11772
# 1999    11842
# 2000    12999
# 2001    14118
# 2002    14400
# 2003    16297
# 2004    18725
# 2005    20255
# 2006    23383
# 2007    22904
# 2008    22344
# 2009    23567
# 2010    24198
# 2011    24790
# 2012    27813
# 2013    29779
# 2014    31410
# 2015    32476
# 2016    32348
# 2017    33214
# 2018    36092
# 2019    40556
# 2020    40328
# 2021    40475
# 2022    43798
# 2023    45350
# 2024    45227
# 2025    44309
# Name: count, dtype: int64

# %%
bi_anomaly_table.to_csv(
    r"../../../data/clean/Yashaswi/Final_Clean/temperature_anomalies.csv",
    index=False
)

# %% [markdown]
# ## Vizualize Anlomalies

# %%
import matplotlib.pyplot as plt

# 1. Keep only non-null anomaly values
anom_df = bi_anomaly_table.dropna(subset=["Temp Anomaly (°C)"])

# 2. Scatter plot (dots only)
plt.figure(figsize=(12, 5))
plt.scatter(
    anom_df["Date"],
    anom_df["Temp Anomaly (°C)"],
    s=5,              # small dots
    alpha=0.5         # transparency for dense data
)

plt.xlabel("Date")
plt.ylabel("Temperature Anomaly (°C)")
plt.title("Temperature Anomalies (Non-null Values Only)")
plt.show()

# %% [markdown]
# ## Filter only severe, non‑null anomalies

# %%
import matplotlib.pyplot as plt

# Keep only non-null anomalies
anom_df = bi_anomaly_table.dropna(subset=["Temp Anomaly (°C)"])

# Define severity threshold
SEVERE_THRESHOLD = 5.0

# Filter severe anomalies (hot OR cold)
severe_anom_df = anom_df[
    (anom_df["Temp Anomaly (°C)"] >= SEVERE_THRESHOLD) |
    (anom_df["Temp Anomaly (°C)"] <= -SEVERE_THRESHOLD)
]

plt.figure(figsize=(12, 5))

plt.scatter(
    severe_anom_df["Date"],
    severe_anom_df["Temp Anomaly (°C)"],
    s=10,
    alpha=0.7
)

plt.axhline(SEVERE_THRESHOLD, linestyle="--")
plt.axhline(-SEVERE_THRESHOLD, linestyle="--")

plt.xlabel("Date")
plt.ylabel("Temperature Anomaly (°C)")
plt.title("Severe Temperature Anomalies (|Anomaly| ≥ 5°C)")
plt.show()

# %% [markdown]
# ## ✅ 1. Check if each station has only ONE row per date (most important)
# ✅ Interpretation
#
# - False → ✅ each station has only one row per date
# - True → ❌ duplicates exist (problem)

# %%
bi_anomaly_table.duplicated(subset=["station_id", "Date"]).any()
# Out:
# np.False_

# %%
bi_anomaly_table.duplicated(
    subset=["station_id", "Date"]
).sum()
# Out:
# np.int64(0)

# %%
baseline_check = (
    bi_anomaly_table
    .groupby(["station_id", "Date"])["Baseline Mean Temp (°C)"]
    .nunique()
)

baseline_check[baseline_check > 1]
# Out:
# Series([], Name: Baseline Mean Temp (°C), dtype: int64)

# %% [markdown]
# ## Monthly anomalies

# %%
monthly_anomaly = (
    df.groupby(["station_id", "Year", "Month"])["Temp Anomaly (°C)"]
      .mean()
      .reset_index()
)

# %% [markdown]
# ## Seasonal anomalies

# %%
season_map = {
    12:"Winter", 1:"Winter", 2:"Winter",
     3:"Spring", 4:"Spring", 5:"Spring",
     6:"Summer", 7:"Summer", 8:"Summer",
     9:"Fall",  10:"Fall",  11:"Fall"
}

df["Season"] = df["Month"].map(season_map)

seasonal_anomaly = (
    df.groupby(["station_id", "Year", "Season"])["Temp Anomaly (°C)"]
      .mean()
      .reset_index()
)
seasonal_anomaly.head()
# Out:
#   station_id  Year  Season  Temp Anomaly (°C)
# 0    8100300  1995    Fall          -0.246746
# 1    8100300  1995  Spring          -1.157469
# 2    8100300  1995  Summer           0.618825
# 3    8100300  1995  Winter          -1.847593
# 4    8100300  1996    Fall          -0.948944

# %%
import matplotlib.pyplot as plt

# Average across all stations per Year & Season
seasonal_avg = (
    seasonal_anomaly
    .groupby(["Year", "Season"])["Temp Anomaly (°C)"]
    .mean()
    .reset_index()
)

plt.figure(figsize=(12, 6))

for season in ["Winter", "Spring", "Summer", "Fall"]:
    data = seasonal_avg[seasonal_avg["Season"] == season]
    plt.plot(
        data["Year"],
        data["Temp Anomaly (°C)"],
        marker="o",
        label=season
    )

plt.axhline(0, linestyle="--")
plt.xlabel("Year")
plt.ylabel("Mean Temperature Anomaly (°C)")
plt.title("Seasonal Temperature Anomalies Over Time")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 5))

season_map_order = {"Winter": 0, "Spring": 1, "Summer": 2, "Fall": 3}
seasonal_avg["Season_num"] = seasonal_avg["Season"].map(season_map_order)

plt.scatter(
    seasonal_avg["Year"],
    seasonal_avg["Season_num"],
    c=seasonal_avg["Temp Anomaly (°C)"],
    cmap="coolwarm",
    s=60
)

plt.yticks(
    list(season_map_order.values()),
    list(season_map_order.keys())
)

plt.colorbar(label="Temp Anomaly (°C)")
plt.xlabel("Year")
plt.ylabel("Season")
plt.title("Seasonal Temperature Anomalies (Color = Magnitude)")
plt.show()

# %%
import matplotlib.pyplot as plt

# Aggregate across stations (optional but recommended for clarity)
seasonal_avg = (
    seasonal_anomaly
    .groupby(["Year", "Season"])["Temp Anomaly (°C)"]
    .mean()
    .reset_index()
)

# Color map for seasons
season_colors = {
    "Winter": "tab:blue",
    "Spring": "tab:green",
    "Summer": "tab:red",
    "Fall": "tab:orange"
}

plt.figure(figsize=(12, 5))

for season, color in season_colors.items():
    data = seasonal_avg[seasonal_avg["Season"] == season]
    plt.scatter(
        data["Year"],
        data["Temp Anomaly (°C)"],
        color=color,
        label=season,
        s=50,
        alpha=0.7
    )

plt.axhline(0, linestyle="--")
plt.xlabel("Year")
plt.ylabel("Mean Temperature Anomaly (°C)")
plt.title("Seasonal Temperature Anomalies (Scatter, Color-Coded by Season)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Long‑term warming trends using temperature anomalies
# - Goal
# Quantify and visualize warming trends over time:
#
# per station
# per province
# nationally (optional)
#
# All trends are based on anomalies, not raw temperature (best practice).

# %%
required_cols = [
    "station_id", "Date", "Year",
    "Temp Anomaly (°C)", "Province"
]

missing = [c for c in required_cols if c not in df.columns]
missing
# Out:
# []

# %% [markdown]
# ## Create annual mean anomalies (station level)

# %%
annual_station_anomaly = (
    df.groupby(["station_id", "Year"], as_index=False)
      ["Temp Anomaly (°C)"]
      .mean()
)

# %% [markdown]
# ## Compute long‑term trend per station
# - This code computes how fast each station is warming or cooling (°C per decade) using a linear trend.
# - Taking temperature anomaly data over time
# - Fitting a straight line for each station
# - Extracting the slope (warming/cooling rate)
# - Expressing it in °C per decade

# %%
import numpy as np

def trend_per_decade(x, y):
    slope, _ = np.polyfit(x, y, 1)
    return slope * 10  # °C / decade

station_trends = (
    annual_station_anomaly
    .groupby("station_id")
    .apply(lambda g: trend_per_decade(g["Year"], g["Temp Anomaly (°C)"]))
    .reset_index(name="Trend (°C / decade)")
)
station_trends.head()
# Out:
#   station_id  Trend (°C / decade)
# 0    8100300             0.446855
# 1    8100467             0.045822
# 2    8100468           -10.809354
# 3    8100506             4.209381
# 4    8100885             0.339130

# %%
import matplotlib.pyplot as plt

plt.hist(station_trends["Trend (°C / decade)"], bins=30)
plt.xlabel("Trend (°C / decade)")
plt.ylabel("Number of stations")
plt.title("Distribution of Station Temperature Trends")
plt.show()

# %% [markdown]
# ## Add columns to station trends for vizualization

# %%
station_trends_viz = station_trends.merge(
    station_meta,
    on="station_id",
    how="left",
    suffixes=("", "_dup")
)

# Drop duplicate columns
#station_trends_viz = station_trends_viz.drop(columns=[
#    "Longitude (x)_dup",
#    "Latitude (y)_dup",
#    "Province_dup"
#])
station_trends_viz
# Out:
#     station_id  Trend (°C / decade)  Longitude (x)  Latitude (y)  \
# 0      8100300             0.446855         -67.72         46.71
# 1      8100467             0.045822         -64.83         47.80
# 2      8100468           -10.809354         -64.87         47.80
# 3      8100506             4.209381         -65.74         47.63
# 4      8100885             0.339130         -66.33         47.99
# ..         ...                  ...            ...           ...
# 131    8502801             3.181867         -61.68         56.55
# 132    8502810             4.749761         -61.68         56.55
# 133    8503249             0.115074         -62.59         58.48
# 134    8504176            -3.067170         -66.86         52.92
# 135    8504177             2.718486         -66.86         52.92
#
#      Station Name                   Province
# 0       AROOSTOOK              NEW BRUNSWICK
# 1    BAS CARAQUET              NEW BRUNSWICK
# 2    BAS CARAQUET              NEW BRUNSWICK
# 3      BATHURST A              NEW BRUNSWICK
# 4     CHARLO AUTO              NEW BRUNSWICK
# ..            ...                        ...
# 131        NAIN A  NEWFOUNDLAND AND LABRADOR
# 132        NAIN A  NEWFOUNDLAND AND LABRADOR
# 133        SAGLEK  NEWFOUNDLAND AND LABRADOR
# 134      WABUSH A  NEWFOUNDLAND AND LABRADOR
# 135      WABUSH A  NEWFOUNDLAND AND LABRADOR
#
# [136 rows x 6 columns]

# %%
plt.scatter(
    station_trends_viz["Longitude (x)"],
    station_trends_viz["Latitude (y)"],
    c=station_trends_viz["Trend (°C / decade)"],
    cmap="coolwarm"
)
plt.colorbar(label="Trend (°C / decade)")
plt.xlabel("Longitude (x)")
plt.ylabel("Latitude (y)")
plt.title("Spatial Distribution of Temperature Trends")
plt.show()

# %%
station_trends = station_trends.merge(
    df[["station_id", "Latitude (y)", "Longitude (x)", "Province"]]
      .drop_duplicates(),
    on="station_id",
    how="left"
)
station_trends.head(3)
# Out:
#   station_id  Trend (°C / decade)  Latitude (y)  Longitude (x)       Province
# 0    8100300             0.446855         46.71         -67.72  NEW BRUNSWICK
# 1    8100467             0.045822         47.80         -64.83  NEW BRUNSWICK
# 2    8100468           -10.809354         47.80         -64.87  NEW BRUNSWICK

# %%
station_trends.to_csv(
    r"../../../data/clean/Yashaswi/Final_Clean/temperature_stationtrends.csv",
    index=False
)

# %% [markdown]
# ## Province‑level warming trends

# %%
annual_province_anomaly = (
    df.groupby(["Province", "Year"], as_index=False)
      ["Temp Anomaly (°C)"]
      .mean()
)

province_trends = (
    annual_province_anomaly
    .groupby("Province")
    .apply(lambda g: trend_per_decade(g["Year"], g["Temp Anomaly (°C)"]))
    .reset_index(name="Trend (°C / decade)")
    .sort_values("Trend (°C / decade)", ascending=False)
)

bi_anomaly_table = bi_anomaly_table.drop(
    columns=[col for col in bi_anomaly_table.columns if "Province" in col],
    errors="ignore"
)

bi_anomaly_table = bi_anomaly_table.merge(
    df[["station_id", "Province"]].drop_duplicates(subset="station_id"),
    on="station_id",
    how="left"
)

# %%
bi_anomaly_table.head()
# Out:
#   station_id       Date  Baseline Mean Temp (°C)  Temp Anomaly (°C)  \
# 0    8204020 2021-09-11                16.540001              -2.84
# 1    8204020 2021-09-12                15.800000               0.30
# 2    8204020 2021-09-13                17.139999              -1.24
# 3    8204020 2021-09-14                15.640000              -3.54
# 4    8204020 2021-09-15                14.300000              -1.30
#
#       Province
# 0  NOVA SCOTIA
# 1  NOVA SCOTIA
# 2  NOVA SCOTIA
# 3  NOVA SCOTIA
# 4  NOVA SCOTIA

# %%
bi_anomaly_table = bi_anomaly_table.merge(province_trends, on="Province", how="left")

# %%
bi_anomaly_table.head()
# Out:
#   station_id       Date  Baseline Mean Temp (°C)  Temp Anomaly (°C)  \
# 0    8204020 2021-09-11                16.540001              -2.84
# 1    8204020 2021-09-12                15.800000               0.30
# 2    8204020 2021-09-13                17.139999              -1.24
# 3    8204020 2021-09-14                15.640000              -3.54
# 4    8204020 2021-09-15                14.300000              -1.30
#
#       Province  Trend (°C / decade)
# 0  NOVA SCOTIA             0.235465
# 1  NOVA SCOTIA             0.235465
# 2  NOVA SCOTIA             0.235465
# 3  NOVA SCOTIA             0.235465
# 4  NOVA SCOTIA             0.235465

# %% [markdown]
# ## check

# %%
station_trends["Trend (°C / decade)"].describe()
province_trends
# Out:
#                     Province  Trend (°C / decade)
# 3       PRINCE EDWARD ISLAND             0.348994
# 1  NEWFOUNDLAND AND LABRADOR             0.251060
# 2                NOVA SCOTIA             0.235465
# 0              NEW BRUNSWICK             0.158325

# %% [markdown]
# # Heatwave Detection Using Temperature Anomalies
# - Definition (clear & climate‑standard)
# We will define a heatwave as:
#
# ≥ 3 consecutive days where
# Daily temperature anomaly ≥ +2.0 °C
# relative to the 30‑year station baseline
#
# ✅ Station‑specific
# ✅ Baseline‑relative
# ✅ Robust across regions
# (Thresholds can be adjusted later.)

# %%
df = df.sort_values(["station_id", "Date"]).reset_index(drop=True)
df.head(3)
# Out:
#   station_id       Date  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0    8100300 1995-01-01           -8.0          -14.0           -11.0
# 1    8100300 1995-01-02           -4.0           -9.0            -6.5
# 2    8100300 1995-01-03           -6.0          -10.5            -8.3
#
#    Heat Deg Days (°C)  Cool Deg Days (°C)  Year  Month  Day  Longitude (x)  \
# 0                29.0                 0.0  1995      1    1         -67.72
# 1                24.5                 0.0  1995      1    2         -67.72
# 2                26.3                 0.0  1995      1    3         -67.72
#
#    Latitude (y) Station Name       Province  Baseline Mean Temp (°C)  \
# 0         46.71    AROOSTOOK  NEW BRUNSWICK                -8.660000
# 1         46.71    AROOSTOOK  NEW BRUNSWICK                -9.565385
# 2         46.71    AROOSTOOK  NEW BRUNSWICK               -10.623077
#
#    Temp Anomaly (°C)  Season
# 0          -2.340000  Winter
# 1           3.065385  Winter
# 2           2.323077  Winter

# %% [markdown]
# ## Flag heatwave‑candidate days

# %%
HEATWAVE_THRESHOLD = 2.0  # °C anomaly

df["hw_day"] = df["Temp Anomaly (°C)"] >= HEATWAVE_THRESHOLD

# %% [markdown]
# ## Identify consecutive heatwave runs per station

# %%
# Start a new group when hw_day changes OR station changes
df["hw_group"] = (
    df["hw_day"]
    .ne(df["hw_day"].shift())
    | df["station_id"].ne(df["station_id"].shift())
).cumsum()

# %% [markdown]
# ## Extract valid heatwave events (≥ 3 days)

# %%
heatwaves = (
    df[df["hw_day"]]
    .groupby(["station_id", "hw_group"])
    .agg(
        start_date=("Date", "min"),
        end_date=("Date", "max"),
        duration_days=("Date", "count"),
        mean_anomaly=("Temp Anomaly (°C)", "mean"),
        max_anomaly=("Temp Anomaly (°C)", "max")
    )
    .reset_index()  # ✅ DO NOT drop index
)
heatwaves = heatwaves[heatwaves["duration_days"] >= 3]

# %%
heatwaves = heatwaves.drop(
    columns=[c for c in heatwaves.columns 
             if c in ["Latitude", "Longitude", "Province", "CSDNAME"]],
    errors="ignore"
)

# %%
heatwaves = heatwaves.merge(
    df[["station_id", "Latitude (y)", "Longitude (x)", "Province"]]
      .drop_duplicates(),
    on="station_id",
    how="left"
)
heatwaves.head()
# Out:
#   station_id  hw_group start_date   end_date  duration_days  mean_anomaly  \
# 0    8100300         4 1995-01-13 1995-01-25             13      9.660637
# 1    8100300        14 1995-03-13 1995-03-19              7      4.779635
# 2    8100300        16 1995-03-21 1995-03-23              3      5.663889
# 3    8100300        18 1995-05-12 1995-05-14              3      4.146667
# 4    8100300        20 1995-05-31 1995-06-03              4      4.324038
#
#    max_anomaly  Latitude (y)  Longitude (x)       Province
# 0    18.404000         46.71         -67.72  NEW BRUNSWICK
# 1     6.195833         46.71         -67.72  NEW BRUNSWICK
# 2     6.395833         46.71         -67.72  NEW BRUNSWICK
# 3     4.616000         46.71         -67.72  NEW BRUNSWICK
# 4     6.500000         46.71         -67.72  NEW BRUNSWICK

# %%
import pandas as pd

heatwaves["start_date"] = pd.to_datetime(heatwaves["start_date"])
heatwaves["end_date"] = pd.to_datetime(heatwaves["end_date"])
heatwaves_2010_2025 = heatwaves[
    (heatwaves["start_date"] >= "2010-01-01") &
    (heatwaves["start_date"] <= "2025-12-31")
]
heatwaves_2010_2025_final = heatwaves_2010_2025[
    [
        "station_id",
        "hw_group",
        "start_date",
        "end_date",
        "duration_days",
        "mean_anomaly",
        "max_anomaly",
    ]
]

# %%
heatwaves_2010_2025_final.head()
# Out:
#     station_id  hw_group start_date   end_date  duration_days  mean_anomaly  \
# 144    8100300       836 2010-01-02 2010-01-08              7      9.250128
# 145    8100300       840 2010-01-19 2010-01-22              4      7.170149
# 146    8100300       842 2010-01-25 2010-01-29              5      8.671077
# 147    8100300       844 2010-02-07 2010-03-09             31      7.950397
# 148    8100300       846 2010-03-13 2010-03-20              8      6.060306
#
#      max_anomaly
# 144    12.668000
# 145    11.344000
# 146    14.234615
# 147    13.004000
# 148     9.587500

# %%
heatwaves_2010_2025_final["start_date"].min(), \
heatwaves_2010_2025_final["start_date"].max()
# Out:
# (Timestamp('2010-01-01 00:00:00'), Timestamp('2025-12-29 00:00:00'))

# %% [markdown]
# ## Export Heatwaves csv

# %%
heatwaves_2010_2025_final.to_csv(
    r"../../../data/clean/Yashaswi/Final_Clean/heatwaves_2010_2025.csv",
    index=False
)

# %% [markdown]
# ## Vizualize Heatwaves

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure dates are datetime
heatwaves["start_date"] = pd.to_datetime(heatwaves["start_date"])

plt.figure(figsize=(12, 5))

plt.scatter(
    heatwaves["start_date"],
    heatwaves["max_anomaly"],
    s=heatwaves["duration_days"] * 6,   # size reflects duration
    alpha=0.7
)

plt.xlabel("Heatwave Start Date")
plt.ylabel("Maximum Temperature Anomaly (°C)")
plt.title("Heatwaves Scatter Plot (Dot Size = Duration in Days)")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 5))

for province in heatwaves["Province"].unique():
    p_df = heatwaves[heatwaves["Province"] == province]
    plt.scatter(
        p_df["start_date"],
        p_df["max_anomaly"],
        s=p_df["duration_days"] * 6,
        alpha=0.6,
        label=province
    )

plt.xlabel("Heatwave Start Date")
plt.ylabel("Maximum Temperature Anomaly (°C)")
plt.title("Heatwaves by Province (Size = Duration)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Export heatwaves file 1995 onwards

# %%
heatwaves.to_csv(
    r"../../../data/clean/Yashaswi/Final_Clean/heatwaves.csv",
    index=False
)

# %% [markdown]
# ## Heatwave frequency analysis

# %%
heatwaves["Year"] = heatwaves["start_date"].dt.year

station_hw_freq = (
    heatwaves.groupby(["station_id", "Year"])
    .size()
    .reset_index(name="heatwave_count")
)

# %%
province_hw_freq = (
    heatwaves.groupby(["Province", "Year"])
    .size()
    .reset_index(name="heatwave_count")
)
province_hw_freq.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province        124 non-null    str
#  1   Year            124 non-null    int32
#  2   heatwave_count  124 non-null    int64
# dtypes: int32(1), int64(1), str(1)
# memory usage: 4.7 KB

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

for province in province_hw_freq["Province"].unique():
    data = province_hw_freq[province_hw_freq["Province"] == province]
    
    plt.scatter(
        data["Year"],
        data["heatwave_count"],
        s=60,
        alpha=0.7,
        label=province
    )

plt.xlabel("Year")
plt.ylabel("Number of Heatwaves")
plt.title("Heatwave Frequency by Province (Scatter Plot)")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
stations_per_province = (
    heatwaves[["Province", "station_id"]]
    .drop_duplicates()
    .groupby("Province")
    .size()
    .reset_index(name="num_stations")
)

stations_per_province
# Out:
#                     Province  num_stations
# 0              NEW BRUNSWICK            27
# 1  NEWFOUNDLAND AND LABRADOR            51
# 2                NOVA SCOTIA            50
# 3       PRINCE EDWARD ISLAND             8

# %%
events_per_station = (
    heatwaves
    .groupby(["Province", "station_id"])
    .size()
    .reset_index(name="heatwave_events")
)
events_per_station.head()
# Out:
#         Province station_id  heatwave_events
# 0  NEW BRUNSWICK    8100300              378
# 1  NEW BRUNSWICK    8100467              387
# 2  NEW BRUNSWICK    8100468                1
# 3  NEW BRUNSWICK    8100506               92
# 4  NEW BRUNSWICK    8100885              280

# %% [markdown]
# ## Heatwave intensity metrics

# %%
heatwaves[[
    "duration_days",
    "mean_anomaly",
    "max_anomaly"
]].describe()
# Out:
#        duration_days  mean_anomaly   max_anomaly
# count   28173.000000  28173.000000  28173.000000
# mean        4.705001      4.759685      6.827130
# std         2.532097      1.493799      2.612855
# min         3.000000      2.045968      2.103226
# 25%         3.000000      3.653083      4.886207
# 50%         4.000000      4.498408      6.380000
# 75%         5.000000      5.604365      8.296667
# max        35.000000     13.931407     21.275000

# %% [markdown]
# # Spatial gradients
# - Where heatwaves are intensifying fastest
# - A) Warming rate vs latitude
# - Use the station‑level warming rates (°C/decade) you already computed earlier.

# %%
# station_trends already exists with:
# ['station_id', 'Trend (°C / decade)', 'Latitude', 'Longitude', 'Province', 'CSDNAME']

station_trends[["Latitude (y)", "Trend (°C / decade)"]].describe()
# Out:
#        Latitude (y)  Trend (°C / decade)
# count    136.000000           136.000000
# mean      47.379265             0.542365
# std        3.051183             2.173891
# min       43.450000           -17.130800
# 25%       45.275000             0.265065
# 50%       46.505000             0.448705
# 75%       48.560000             0.966401
# max       58.480000             5.086687

# %%
station_trends[["Latitude (y)", "Trend (°C / decade)"]].corr()
# Out:
#                      Latitude (y)  Trend (°C / decade)
# Latitude (y)             1.000000             0.015645
# Trend (°C / decade)      0.015645             1.000000

# %% [markdown]
# ## Bin by latitude bands (clear climate signal)
# - Interpretation: higher latitudes warming faster is a classic fingerprint; deviations tell regional stories.

# %%
station_trends["lat_band"] = pd.cut(
    station_trends["Latitude (y)"],
    bins=[40, 45, 50, 55, 60],
    labels=["40–45", "45–50", "50–55", "55–60"]
)

lat_band_trends = (
    station_trends
    .groupby("lat_band")["Trend (°C / decade)"]
    .mean()
    .reset_index()
)
lat_band_trends
# Out:
#   lat_band  Trend (°C / decade)
# 0    40–45             0.587275
# 1    45–50             0.502393
# 2    50–55            -0.027254
# 3    55–60             2.131585

# %% [markdown]
# ## Heatwave intensity vs latitude

# %%
hw_lat = (
    heatwaves
    .groupby("station_id", as_index=False)
    .agg(
        mean_hw_duration=("duration_days", "mean"),
        max_hw_anomaly=("max_anomaly", "max")
    )
    .merge(
        station_trends[["station_id", "Latitude (y)"]],
        on="station_id",
        how="left"
    )
)
hw_lat_numeric = hw_lat[
    ["Latitude (y)", "mean_hw_duration", "max_hw_anomaly"]
]

hw_lat_numeric.corr()
# Out:
#                   Latitude (y)  mean_hw_duration  max_hw_anomaly
# Latitude (y)          1.000000          0.645703        0.231122
# mean_hw_duration      0.645703          1.000000        0.433781
# max_hw_anomaly        0.231122          0.433781        1.000000

# %%
hw_lat.dtypes
# Out:
# station_id           object
# mean_hw_duration    float64
# max_hw_anomaly      float64
# Latitude (y)        float64
# dtype: object

# %% [markdown]
# # Trend in heatwaves
# - Are heatwaves becoming more frequent/longer?
#
# - Interpretation:
#
# ↑ frequency → more frequent blocking patterns
# ↑ duration → more persistent extremes (higher risk)

# %% [markdown]
# ## Event frequency per year

# %%
annual_hw_count = (
    heatwaves
    .groupby("Year")
    .size()
    .reset_index(name="heatwave_events")
)

annual_hw_count.head()
# Out:
#    Year  heatwave_events
# 0  1995              222
# 1  1996              380
# 2  1997              138
# 3  1998              352
# 4  1999              577

# %%
heatwaves.groupby("Year")["station_id"].nunique().head()
# Out:
# Year
# 1995    33
# 1996    34
# 1997    34
# 1998    33
# 1999    35
# Name: station_id, dtype: int64

# %% [markdown]
# ## Trend (events per decade)

# %%
import numpy as np

slope_events_per_decade = (
    np.polyfit(
        annual_hw_count["Year"],
        annual_hw_count["heatwave_events"],
        1
    )[0] * 10
)

slope_events_per_decade
# Out:
# np.float64(506.91935483871595)

# %% [markdown]
# ## Duration trend

# %%
annual_hw_duration = (
    heatwaves
    .groupby("Year")["duration_days"]
    .mean()
    .reset_index(name="mean_duration")
)

duration_trend_per_decade = (
    np.polyfit(
        annual_hw_duration["Year"],
        annual_hw_duration["mean_duration"],
        1
    )[0] * 10
)

duration_trend_per_decade
# Out:
# np.float64(-0.005538177776793758)

# %% [markdown]
# # Viz

# %% [markdown]
# ## Long‑term temperature anomaly trend (Atlantic mean)
# - Purpose: Shows climate change signal clearly (noise removed)

# %%
import matplotlib.pyplot as plt

annual_anomaly = (
    df.groupby("Year")["Temp Anomaly (°C)"]
      .mean()
      .reset_index()
)

plt.figure(figsize=(8,4))
plt.plot(annual_anomaly["Year"], annual_anomaly["Temp Anomaly (°C)"])
plt.axhline(0, linestyle="--")
plt.title("Annual Mean Temperature Anomaly (Relative to 30‑Year Baseline)")
plt.xlabel("Year")
plt.ylabel("Temperature Anomaly (°C)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Monthly anomaly climatology
# - Purpose: Seasonality of warming
# - ✅ Shows winter amplification vs summer extremes.

# %%
monthly_anomaly = (
    df.groupby("Month")["Temp Anomaly (°C)"]
      .mean()
)

plt.figure(figsize=(8,4))
monthly_anomaly.plot(kind="bar")
plt.axhline(0, linestyle="--")
plt.title("Mean Monthly Temperature Anomalies")
plt.xlabel("Month")
plt.ylabel("Temperature Anomaly (°C)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Total heatwave events per year (all stations)
# - Purpose: National exposure / climate burden
# ⚠️ Reminder: this is not per station — it is total exposure.

# %%
annual_hw_events = (
    heatwaves.groupby("Year")
    .size()
    .reset_index(name="Total Heatwave Events")
)

plt.figure(figsize=(8,4))
plt.plot(annual_hw_events["Year"], annual_hw_events["Total Heatwave Events"])
plt.title("Total Heatwave Events per Year (All Stations)")
plt.xlabel("Year")
plt.ylabel("Number of Heatwave Events")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Average heatwaves per station per year (best practice trend)
# - Purpose: Proper climate signal

# %%
avg_hw_per_station = (
    heatwaves
    .groupby(["station_id", "Year"])
    .size()
    .groupby("Year")
    .mean()
    .reset_index(name="Avg Heatwaves per Station")
)

plt.figure(figsize=(8,4))
plt.plot(avg_hw_per_station["Year"], avg_hw_per_station["Avg Heatwaves per Station"])
plt.title("Average Heatwaves per Station per Year")
plt.xlabel("Year")
plt.ylabel("Heatwaves per Station")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Heatwave duration trend
# - ✅ Rising duration = more dangerous extremes.

# %%
mean_hw_duration = (
    heatwaves.groupby("Year")["duration_days"]
    .mean()
    .reset_index()
)

plt.figure(figsize=(8,4))
plt.plot(mean_hw_duration["Year"], mean_hw_duration["duration_days"])
plt.title("Mean Heatwave Duration per Year")
plt.xlabel("Year")
plt.ylabel("Duration (days)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Heatwave intensity vs latitude (spatial gradient)

# %%
heatwaves.head()
# Out:
#   station_id  hw_group start_date   end_date  duration_days  mean_anomaly  \
# 0    8100300         4 1995-01-13 1995-01-25             13      9.660637
# 1    8100300        14 1995-03-13 1995-03-19              7      4.779635
# 2    8100300        16 1995-03-21 1995-03-23              3      5.663889
# 3    8100300        18 1995-05-12 1995-05-14              3      4.146667
# 4    8100300        20 1995-05-31 1995-06-03              4      4.324038
#
#    max_anomaly  Latitude (y)  Longitude (x)       Province  Year
# 0    18.404000         46.71         -67.72  NEW BRUNSWICK  1995
# 1     6.195833         46.71         -67.72  NEW BRUNSWICK  1995
# 2     6.395833         46.71         -67.72  NEW BRUNSWICK  1995
# 3     4.616000         46.71         -67.72  NEW BRUNSWICK  1995
# 4     6.500000         46.71         -67.72  NEW BRUNSWICK  1995

# %%
hw_lat = (
    heatwaves
    .groupby("station_id", as_index=False)
    .agg(
        mean_duration=("duration_days", "mean"),
        max_intensity=("max_anomaly", "max"),
        Latitude =("Latitude (y)", "first")
    )
)

plt.figure(figsize=(6,4))
plt.scatter(hw_lat["Latitude"], hw_lat["max_intensity"])
plt.xlabel("Latitude")
plt.ylabel("Maximum Heatwave Anomaly (°C)")
plt.title("Heatwave Intensity vs Latitude")
plt.tight_layout()
plt.show()

# %% [markdown]
# #  Province‑level temperature anomalies

# %%
province_annual_anomaly = (
    df.groupby(["Province", "Year"], as_index=False)
      ["Temp Anomaly (°C)"]
      .mean()
)

# %% [markdown]
# ## Rank provinces by warming trend

# %%
import numpy as np

province_trends = (
    province_annual_anomaly
    .groupby("Province")
    .apply(
        lambda g: np.polyfit(
            g["Year"], g["Temp Anomaly (°C)"], 1
        )[0] * 10   # °C per decade
    )
    .reset_index(name="Warming Rate (°C / decade)")
    .sort_values("Warming Rate (°C / decade)", ascending=False)
)

province_trends
# Out:
#                     Province  Warming Rate (°C / decade)
# 3       PRINCE EDWARD ISLAND                    0.348994
# 1  NEWFOUNDLAND AND LABRADOR                    0.251060
# 2                NOVA SCOTIA                    0.235465
# 0              NEW BRUNSWICK                    0.158325

# %% [markdown]
# # Temperature trend estimation: Linear & Polynomial fits
# - Linear & Polynomial Fits Using Anomalies
# - Scope (explicit and correct)
#
# Region: Atlantic Canada
# Provinces: NS, NB, NL, PEI
# Variable: Temperature anomalies (°C)
# Baseline: Your 30‑year station‑level baseline
# Temporal resolution: Annual means (required for trends)

# %% [markdown]
# ##  Define Atlantic Canada subset

# %%
atlantic_provinces = [
    "NOVA SCOTIA",
    "NEW BRUNSWICK",
    "NEWFOUNDLAND AND LABRADOR",
    "PRINCE EDWARD ISLAND"
]

df_atlantic = df[df["Province"].isin(atlantic_provinces)].copy()

# %% [markdown]
# ## Step 2 — Compute Atlantic‑wide annual mean anomaly

# %%
atlantic_annual_anomaly = (
    df_atlantic
    .groupby("Year")["Temp Anomaly (°C)"]
    .mean()
    .reset_index()
)

# %% [markdown]
# # PART A — Linear trend (primary result)
# - ✅ Step 3 — Linear regression (°C per decade)
# - ✅ Interpretation
#
# Atlantic Canada has warmed at a rate of X °C per decade,
# relative to the chosen 30‑year baseline.
#
# This is the number you report in text, tables, and abstracts.

# %%
atlantic_annual_anomaly.head(3)
# Out:
#    Year  Temp Anomaly (°C)
# 0  1995          -1.050455
# 1  1996          -0.416414
# 2  1997          -1.477448

# %%
import numpy as np

slope, intercept = np.polyfit(
    atlantic_annual_anomaly["Year"],
    atlantic_annual_anomaly["Temp Anomaly (°C)"],
    1
)

atlantic_trend_c_per_decade = slope * 10
atlantic_trend_c_per_decade
# Out:
# np.float64(0.23557442243138968)

# %% [markdown]
# ## ✅ Step 4 — Plot linear trend

# %%
import numpy as np
import matplotlib.pyplot as plt

# Recompute linear regression (safe even if already done)
slope, intercept = np.polyfit(
    atlantic_annual_anomaly["Year"],
    atlantic_annual_anomaly["Temp Anomaly (°C)"],
    1
)

trend_per_decade = slope * 10

# Plot
plt.figure(figsize=(8,4))

plt.plot(
    atlantic_annual_anomaly["Year"],
    atlantic_annual_anomaly["Temp Anomaly (°C)"],
    label="Observed (Atlantic Canada)"
)

plt.plot(
    atlantic_annual_anomaly["Year"],
    slope * atlantic_annual_anomaly["Year"] + intercept,
    linestyle="--",
    label=f"Linear trend ({trend_per_decade:.2f} °C/decade)"
)

plt.axhline(0, linestyle=":")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Temperature Anomaly (°C)")
plt.title("Atlantic Canada Annual Mean Temperature Anomaly")
plt.tight_layout()
plt.show()

# %%
len(df)
# Out:
# 818993

# %%
df["Province"].value_counts()
# Out:
# Province
# NEWFOUNDLAND AND LABRADOR    310108
# NOVA SCOTIA                  281710
# NEW BRUNSWICK                166292
# PRINCE EDWARD ISLAND          60883
# Name: count, dtype: int64

# %% [markdown]
# # 🟧 PART B — Polynomial fit (secondary / diagnostic)
# -Polynomial fits are not a replacement for linear trends.
# They are used to explore non‑linearity or acceleration.

# %% [markdown]
# ## Step 5 — Quadratic (2nd‑order) fit

# %%
coeffs_2 = np.polyfit(
    atlantic_annual_anomaly["Year"],
    atlantic_annual_anomaly["Temp Anomaly (°C)"],
    2
)

poly2 = np.poly1d(coeffs_2)

# %% [markdown]
# ## Step 6 — Compare linear vs polynomial fits

# %%
plt.figure(figsize=(8,4))

plt.plot(
    atlantic_annual_anomaly["Year"],
    atlantic_annual_anomaly["Temp Anomaly (°C)"],
    label="Observed",
    alpha=0.6
)

plt.plot(
    atlantic_annual_anomaly["Year"],
    slope * atlantic_annual_anomaly["Year"] + intercept,
    linestyle="--",
    label="Linear fit"
)

plt.plot(
    atlantic_annual_anomaly["Year"],
    poly2(atlantic_annual_anomaly["Year"]),
    label="Quadratic fit"
)

plt.axhline(0, linestyle=":")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Temperature Anomaly (°C)")
plt.title("Atlantic Canada: Linear vs Polynomial Trend")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🟩 PART C — Province‑level linear trends (recommended)
# This answers:
#
# “Which Atlantic provinces are warming fastest?”

# %%
province_annual_anomaly = (
    df_atlantic
    .groupby(["Province", "Year"])["Temp Anomaly (°C)"]
    .mean()
    .reset_index()
)

province_trends = (
    province_annual_anomaly
    .groupby("Province")
    .apply(
        lambda g: np.polyfit(
            g["Year"],
            g["Temp Anomaly (°C)"],
            1
        )[0] * 10
    )
    .reset_index(name="Trend (°C / decade)")
    .sort_values("Trend (°C / decade)", ascending=False)
)

province_trends
# Out:
#                     Province  Trend (°C / decade)
# 3       PRINCE EDWARD ISLAND             0.348994
# 1  NEWFOUNDLAND AND LABRADOR             0.251060
# 2                NOVA SCOTIA             0.235465
# 0              NEW BRUNSWICK             0.158325

# %% [markdown]
# Bottom‑line interpretation of the plot
#
# Atlantic Canada has experienced sustained regional warming since the mid‑1990s, with recent decades dominated by positive temperature anomalies. A linear trend adequately captures the long‑term warming signal, while year‑to‑year variability reflects natural climate fluctuations.

# %% [markdown]
# ## Provincial insights

# %% [markdown]
# ### 🔥 Prince Edward Island (fastest warming)
#
# ~0.35 °C per decade
# Roughly 1 °C of warming over ~30 years
# Small land area + maritime influence → strong sensitivity
#
# ✅ This is a notable and policy‑relevant signal.

# %% [markdown]
# ### 🌊 Newfoundland and Labrador
#
# ~0.25 °C per decade
# Strong regional warming despite North Atlantic variability
# Likely influenced by:
#
# ocean circulation changes,
# reduced cold extremes.

# %% [markdown]
# ### 🌬️ Nova Scotia
#
# ~0.24 °C per decade
# Consistent warming, moderated by strong marine influence

# %% [markdown]
# ### 🌲 New Brunswick (slowest, but still warming)
#
# ~0.14 °C per decade
# Still clearly positive — no province shows cooling
#
# ✅ Important point:
# Lower does not mean negligible — this is still significant warming over multi‑decadal periods.
