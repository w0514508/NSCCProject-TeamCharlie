# %% [markdown]
# ## Filter each AQI__2010_2024.csv

# %%
#pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-24.0.0-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# Downloading pyarrow-24.0.0-cp312-cp312-win_amd64.whl (27.4 MB)
#    ---------------------------------------- 0.0/27.4 MB ? eta -:--:--
#    ---------------------------------------  27.3/27.4 MB 157.0 MB/s eta 0:00:01
#    ---------------------------------------  27.3/27.4 MB 157.0 MB/s eta 0:00:01
#    ---------------------------------------- 27.4/27.4 MB 52.5 MB/s  0:00:00
# Installing collected packages: pyarrow
# Successfully installed pyarrow-24.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pathlib import Path

INPUT_DIR = Path("../../clean/Yashaswi/DimPollutants/")
OUTPUT_DIR = Path("../../clean/Yashaswi/DimPollutants/Pollutants2015/")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

START_DATE = "2015-01-01"
END_DATE = "2024-12-31"

for csv_file in INPUT_DIR.glob("AQI_*_2010_2024.csv"):
    print(f"Filtering {csv_file.name}")

    df = pd.read_csv(csv_file, parse_dates=["Date"])

    df_filtered = df[
        (df["Date"] >= START_DATE) &
        (df["Date"] <= END_DATE)
    ]

    out_file = OUTPUT_DIR / csv_file.name.replace(
        "2010_2024", "2015_2024"
    )

    df_filtered.to_csv(out_file, index=False)

    print(f"✅ Saved {out_file.name}: {len(df_filtered):,} rows")

print("🎯 All pollutant files filtered")
# Out:
# Filtering AQI_CO_2010_2024.csv
# ✅ Saved AQI_CO_2015_2024.csv: 223,006 rows
# Filtering AQI_NO2_2010_2024.csv
# ✅ Saved AQI_NO2_2015_2024.csv: 676,080 rows
# Filtering AQI_O3_2010_2024.csv
# ✅ Saved AQI_O3_2015_2024.csv: 804,863 rows
# Filtering AQI_PM10_2010_2024.csv
# ✅ Saved AQI_PM10_2015_2024.csv: 138,338 rows
# Filtering AQI_PM2.5_2010_2024.csv
# ✅ Saved AQI_PM2.5_2015_2024.csv: 733,696 rows
# Filtering AQI_SO2_2010_2024.csv
# ✅ Saved AQI_SO2_2015_2024.csv: 507,332 rows
# 🎯 All pollutant files filtered

# %%
import pandas as pd
from pathlib import Path

INPUT_DIR = Path("../../clean/Yashaswi/DimPollutants/Pollutants2015/")
OUTPUT_DIR = Path("../../clean/Yashaswi/DimPollutants/Pollutants2015_Parquet/")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

DTYPES = {
    "NAPS ID": "int32",
    "AQI": "float32",          # AQI does NOT need float64
    "Pollutant": "category"   # HUGE compression win
}

for csv_file in INPUT_DIR.glob("AQI_*_2015_2024.csv"):
    print(f"Optimizing {csv_file.name}")

    df = pd.read_csv(
        csv_file,
        dtype=DTYPES,
        parse_dates=["Date"]
    )

    out_file = OUTPUT_DIR / csv_file.with_suffix(".parquet").name
    df.to_parquet(
        out_file,
        compression="snappy",
        index=False
    )

    print(f"✅ Saved {out_file.name}")

print("🎯 All files converted to Parquet")
# Out:
# Optimizing AQI_CO_2015_2024.csv
# ✅ Saved AQI_CO_2015_2024.parquet
# Optimizing AQI_NO2_2015_2024.csv
# ✅ Saved AQI_NO2_2015_2024.parquet
# Optimizing AQI_O3_2015_2024.csv
# ✅ Saved AQI_O3_2015_2024.parquet
# Optimizing AQI_PM10_2015_2024.csv
# ✅ Saved AQI_PM10_2015_2024.parquet
# Optimizing AQI_PM2.5_2015_2024.csv
# ✅ Saved AQI_PM2.5_2015_2024.parquet
# Optimizing AQI_SO2_2015_2024.csv
# ✅ Saved AQI_SO2_2015_2024.parquet
# 🎯 All files converted to Parquet

# %% [markdown]
# ## ✅ Script 2: Filter consolidated Station wise daily AQI file

# %%
import pandas as pd

# Read original consolidated daily AQI file
df = pd.read_csv(
    "AQI_2010_2024.csv",
    parse_dates=["Date"]
)

# Filter date range
df = df[
    (df["Date"] >= "2015-01-01") &
    (df["Date"] <= "2024-12-31")
]

# ✅ Optimize dtypes for Power BI
df["NAPS ID"] = df["NAPS ID"].astype("int32")
df["AQI"] = df["AQI"].astype("float32")

# If present (very likely)
if "Dominant_Pollutant" in df.columns:
    df["Dominant_Pollutant"] = df["Dominant_Pollutant"].astype("category")

# Save as Parquet (Power BI–optimized)
df.to_parquet(
    "AQI_2015_2024.parquet",
    compression="snappy",
    index=False
)

print(f"✅ Rows after filtering: {len(df):,}")
# Out:
# ✅ Rows after filtering: 981,507

# %%
import pandas as pd

# Load AQI data (Parquet)
aqi = pd.read_parquet("AQI_2015_2024.parquet")

# Load station master list
stations = pd.read_csv("../../raw/Yashaswi/AQI/NAPS Stations.csv")

# %%
null_naps = aqi["NAPS ID"].isna().sum()

print(f"🚨 AQI rows with NULL NAPS ID: {null_naps}")
# Out:
# 🚨 AQI rows with NULL NAPS ID: 0

# %%
aqi[aqi["NAPS ID"].isna()].head()
# Out:
# Empty DataFrame
# Columns: [NAPS ID, Date, AQI, Dominant_Pollutant]
# Index: []

# %%
missing_in_stations = set(aqi["NAPS ID"]) - set(stations["NAPS_ID"])

print(f"⚠ AQI NAPS IDs not found in station file: {len(missing_in_stations)}")
# Out:
# ⚠ AQI NAPS IDs not found in station file: 313

# %%
print(stations.columns)
# Out:
# Index(['NAPS_ID', 'Station_Name', 'City', 'Province/Territory_EN', 'Latitude',
#        'Longitude', 'Elevation_m', 'Start_Date_Station_yyyy_mm_dd'],
#       dtype='str')

# %%
aqi["NAPS_ID"] = aqi["NAPS ID"].astype("int32")
stations["NAPS_ID"] = stations["NAPS_ID"].astype("int32")

# %%
missing_in_stations = set(aqi["NAPS_ID"]) - set(stations["NAPS_ID"])
print(len(missing_in_stations))
# Out:
# 313

# %%
missing_rows = aqi[aqi["NAPS_ID"].isin(missing_in_stations)]

print(f"AQI rows affected: {len(missing_rows):,}")
# Out:
# AQI rows affected: 812,856

# %%
import pandas as pd

stations_naps = pd.read_csv("../../clean/Yashaswi/DimPollutants/StationsNAPS.csv")

print(stations_naps.columns)
print("Unique NAPS IDs:", stations_naps["NAPS_ID"].nunique())
# Out:
# Index(['*Stations2024', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42'],
#       dtype='str')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\ds312\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NAPS_ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 6
#       3 stations_naps = pd.read_csv("../../clean/Yashaswi/DimPollutants/StationsNAPS.csv")
#       5 print(stations_naps.columns)
# ----> 6 print("Unique NAPS IDs:", stations_naps["NAPS_ID"].nunique())
#
# File ~\anaconda3\envs\ds312\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File ~\anaconda3\envs\ds312\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'NAPS_ID'

# %%
import pandas as pd

# Read raw file without headers
raw = pd.read_csv("../../clean/Yashaswi/DimPollutants/StationsNAPS.csv", header=None)

# Find the row where the real header starts
header_row = raw.index[raw[0] == "NAPS_ID"][0]

# Re-read using that row as header
stations = pd.read_csv(
    "../../clean/Yashaswi/DimPollutants/StationsNAPS.csv",
    header=header_row
)

stations.head()
# Out:
#             NAPS_ID              Station_Name  Status  \
# 0  Identifiant_SNPA         Nom_de_la_station  Statut
# 1             10101     DUCKWORTH & ORDINANCE       0
# 2             10102  WATER STREET POST OFFICE       1
# 3             10301              CREDIT UNION       0
# 4             10401               MOUNT PEARL       1
#
#            Location_Address          City      Province/Territory_EN  \
# 0  Adresse_de_l'emplacement         Ville      Province/Territory_EN
# 1     DUCKWORTH & ORDINANCE    ST. JOHN'S  NEWFOUNDLAND AND LABRADOR
# 2          354 WATER STREET    ST. JOHN'S  NEWFOUNDLAND AND LABRADOR
# 3              BROOK STREET  CORNER BROOK  NEWFOUNDLAND AND LABRADOR
# 4        OLD PLACENTIA ROAD   MOUNT PEARL  NEWFOUNDLAND AND LABRADOR
#
#     Province/territoire_FR  Postal_Code        Timezone_UTC   Latitude  ...  \
# 0   Province/territoire_FR  Code_postal  Fuseau_horaire_TUC   Latitude  ...
# 1  TERRE-NEUVE-ET-LABRADOR      A1C 1E4                -3.5   47.56806  ...
# 2  TERRE-NEUVE-ET-LABRADOR      A1C 1C4                -3.5   47.56038  ...
# 3  TERRE-NEUVE-ET-LABRADOR      A2H 2T7                -3.5  48.949479  ...
# 4  TERRE-NEUVE-ET-LABRADOR      A1N 4P4                -3.5   47.50513  ...
#
#    Urbanization Neighbourhood            Land_Use    Scale  \
# 0  Urbanisation      Quartier  Utilisation_du_sol  Échelle
# 1            LU            P4                   R        N
# 2            LU            P4                   C        N
# 3            SU            P3                   I        N
# 4            LU            P3                   R        N
#
#                    PC                   CD                    CSD  \
# 0                  CP                   DR                    SDR
# 1    0792. St. John's  01. Division No.  1    519. St. John's, CY
# 2    0792. St. John's  01. Division No.  1    519. St. John's, CY
# 3  0204. Corner Brook  05. Division No.  5  018. Corner Brook, CY
# 4    0792. St. John's  01. Division No.  1   542. Mount Pearl, CY
#
#                      CMA/CA                              AQMS_Airzone  \
# 0                    RMR/AR                   SGQA_zone_atmosphérique
# 1  001. St. John's, CMA/RMR  Newfoundland and Labrador - Newfoundland
# 2  001. St. John's, CMA/RMR  Newfoundland and Labrador - Newfoundland
# 3  015. Corner Brook, CA/AR  Newfoundland and Labrador - Newfoundland
# 4  001. St. John's, CMA/RMR  Newfoundland and Labrador - Newfoundland
#
#         Core_Site
# 0  Site_principal
# 1             NaN
# 2               2
# 3             NaN
# 4             NaN
#
# [5 rows x 43 columns]

# %%
stations.columns
# Out:
# Index(['NAPS_ID', 'Station_Name', 'Status', 'Location_Address', 'City',
#        'Province/Territory_EN', 'Province/territoire_FR', 'Postal_Code',
#        'Timezone_UTC', 'Latitude', 'Longitude', 'Elevation_m', 'Start_Date',
#        'End_Date', 'Combined_Stations', 'Inlet_Height_m', 'Network', 'SO2',
#        'CO', 'NO2', 'NO', 'NOX', 'O3', 'PM2.5_Continuous', 'PM10_Continuous',
#        'PM2.5_RM', 'PM10_Integrated', 'PM2.5-10', 'PM2.5_Speciation', 'VOC',
#        'Carbonyl', 'PAC', 'Site_Type', 'Urbanization', 'Neighbourhood',
#        'Land_Use', 'Scale', 'PC', 'CD', 'CSD', 'CMA/CA', 'AQMS_Airzone',
#        'Core_Site'],
#       dtype='str')

# %%
stations[stations["NAPS_ID"].isna()]
# Out:
#     NAPS_ID Station_Name Status Location_Address City Province/Territory_EN  \
# 655     NaN          NaN    NaN              NaN  NaN                   NaN
# 673     NaN          NaN    NaN              NaN  NaN                   NaN
# 716     NaN          NaN    NaN              NaN  NaN                   NaN
# 719     NaN          NaN    NaN              NaN  NaN                   NaN
# 722     NaN          NaN    NaN              NaN  NaN                   NaN
# 726     NaN          NaN    NaN              NaN  NaN                   NaN
# 730     NaN          NaN    NaN              NaN  NaN                   NaN
# 734     NaN          NaN    NaN              NaN  NaN                   NaN
# 738     NaN          NaN    NaN              NaN  NaN                   NaN
# 744     NaN          NaN    NaN              NaN  NaN                   NaN
# 750     NaN          NaN    NaN              NaN  NaN                   NaN
# 754     NaN          NaN    NaN              NaN  NaN                   NaN
# 760     NaN          NaN    NaN              NaN  NaN                   NaN
#
#     Province/territoire_FR Postal_Code Timezone_UTC Latitude  ...  \
# 655                    NaN         NaN          NaN      NaN  ...
# 673                    NaN         NaN          NaN      NaN  ...
# 716                    NaN         NaN          NaN      NaN  ...
# 719                    NaN         NaN          NaN      NaN  ...
# 722                    NaN         NaN          NaN      NaN  ...
# 726                    NaN         NaN          NaN      NaN  ...
# 730                    NaN         NaN          NaN      NaN  ...
# 734                    NaN         NaN          NaN      NaN  ...
# 738                    NaN         NaN          NaN      NaN  ...
# 744                    NaN         NaN          NaN      NaN  ...
# 750                    NaN         NaN          NaN      NaN  ...
# 754                    NaN         NaN          NaN      NaN  ...
# 760                    NaN         NaN          NaN      NaN  ...
#
#     Urbanization Neighbourhood Land_Use Scale   PC   CD  CSD CMA/CA  \
# 655          NaN           NaN      NaN   NaN  NaN  NaN  NaN    NaN
# 673          NaN           NaN      NaN   NaN  NaN  NaN  NaN    NaN
# 716          NaN           NaN      NaN   NaN  NaN  NaN  NaN    NaN
# 719          NaN           NaN      NaN   NaN  NaN  NaN  NaN    NaN
# 722          NaN           NaN      NaN   NaN  NaN  NaN  NaN    NaN
# 726          NaN           NaN      NaN   NaN  NaN  NaN  NaN    NaN
# 730          NaN           NaN      NaN   NaN  NaN  NaN  NaN    NaN
# 734          NaN           NaN      NaN   NaN  NaN  NaN  NaN    NaN
# 738          NaN           NaN      NaN   NaN  NaN  NaN  NaN    NaN
# 744          NaN           NaN      NaN   NaN  NaN  NaN  NaN    NaN
# 750          NaN           NaN      NaN   NaN  NaN  NaN  NaN    NaN
# 754          NaN           NaN      NaN   NaN  NaN  NaN  NaN    NaN
# 760          NaN           NaN      NaN   NaN  NaN  NaN  NaN    NaN
#
#     AQMS_Airzone Core_Site
# 655          NaN       NaN
# 673          NaN       NaN
# 716          NaN       NaN
# 719          NaN       NaN
# 722          NaN       NaN
# 726          NaN       NaN
# 730          NaN       NaN
# 734          NaN       NaN
# 738          NaN       NaN
# 744          NaN       NaN
# 750          NaN       NaN
# 754          NaN       NaN
# 760          NaN       NaN
#
# [13 rows x 43 columns]

# %%
stations = stations.dropna(subset=["NAPS_ID"])

# %%
stations["NAPS_ID"] = pd.to_numeric(
    stations["NAPS_ID"],
    errors="coerce"
)

# %%
stations = stations.dropna(subset=["NAPS_ID"])

# %%
stations["NAPS_ID"] = stations["NAPS_ID"].astype("int32")

# %%
stations["NAPS_ID"].isna().sum()
# Out:
# np.int64(0)

# %%
aqi["NAPS_ID"] = aqi["NAPS_ID"].astype("int32")

missing_in_stations = set(aqi["NAPS_ID"]) - set(stations["NAPS_ID"])
print("Missing NAPS IDs:", len(missing_in_stations))
# Out:
# Missing NAPS IDs: 0

# %%
stations.columns
# Out:
# Index(['NAPS_ID', 'Station_Name', 'Status', 'Location_Address', 'City',
#        'Province/Territory_EN', 'Province/territoire_FR', 'Postal_Code',
#        'Timezone_UTC', 'Latitude', 'Longitude', 'Elevation_m', 'Start_Date',
#        'End_Date', 'Combined_Stations', 'Inlet_Height_m', 'Network', 'SO2',
#        'CO', 'NO2', 'NO', 'NOX', 'O3', 'PM2.5_Continuous', 'PM10_Continuous',
#        'PM2.5_RM', 'PM10_Integrated', 'PM2.5-10', 'PM2.5_Speciation', 'VOC',
#        'Carbonyl', 'PAC', 'Site_Type', 'Urbanization', 'Neighbourhood',
#        'Land_Use', 'Scale', 'PC', 'CD', 'CSD', 'CMA/CA', 'AQMS_Airzone',
#        'Core_Site'],
#       dtype='str')

# %%
dim_station = stations[
    [
        "NAPS_ID",
        "Station_Name",
        "City",
        "Province/Territory_EN",
        "Latitude",
        "Longitude",
        "Status",
        "Start_Date",
        "End_Date"
    ]
]

# %%
province_map = {
    "NEWFOUNDLAND AND LABRADOR": "NL",
    "PRINCE EDWARD ISLAND": "PE",
    "NOVA SCOTIA": "NS",
    "NEW BRUNSWICK": "NB",
    "QUEBEC": "QC",
    "ONTARIO": "ON",
    "MANITOBA": "MB",
    "SASKATCHEWAN": "SK",
    "ALBERTA": "AB",
    "BRITISH COLUMBIA": "BC",
    "YUKON": "YT",
    "NORTHWEST TERRITORIES": "NT",
    "NUNAVUT": "NU"
}

# %%
dim_station["Province_Code"] = (
    dim_station["Province/Territory_EN"]
    .str.upper()
    .map(province_map)
)

# %%
dim_station[
    dim_station["Province_Code"].isna()
][["Province/Territory_EN"]].drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [Province/Territory_EN]
# Index: []

# %%
dim_station = dim_station[
    [
        "NAPS_ID",
        "Station_Name",
        "City",
        "Province/Territory_EN",
        "Province_Code",
        "Latitude",
        "Longitude",
        "Status",
        "Start_Date",
        "End_Date"
    ]
] = dim_station[
    [
        "NAPS_ID",
        "Station_Name",
        "City",
        "Province/Territory_EN",
        "Province_Code",
        "Latitude",
        "Longitude",
        "Status",
        "Start_Date",
        "End_Date"
    ]
]

# %%
dim_station.to_csv(
    "Dim_Station_NAPS.csv",
    index=False
)
