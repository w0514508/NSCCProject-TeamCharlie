# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_raw = pd.read_csv("../../../data/raw/Michael/Raw Data for GHG Emissions by Province and Territories.csv")
df_clean = pd.read_csv("../../../data/clean/Michael/Cleaned GHG Emissions Data by Provices and Territories.csv")

# %%
df_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 770 entries, 0 to 769
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   REF_DATE       770 non-null    int64
#  1   GEO            770 non-null    str
#  2   DGUID          770 non-null    str
#  3   Sector         770 non-null    str
#  4   UOM            770 non-null    str
#  5   UOM_ID         770 non-null    int64
#  6   SCALAR_FACTOR  770 non-null    str
#  7   SCALAR_ID      770 non-null    int64
#  8   VECTOR         770 non-null    str
#  9   COORDINATE     770 non-null    float64
#  10  VALUE          770 non-null    int64
#  11  STATUS         0 non-null      float64
#  12  SYMBOL         0 non-null      float64
#  13  TERMINATED     0 non-null      float64
#  14  DECIMALS       770 non-null    int64
# dtypes: float64(4), int64(5), str(6)
# memory usage: 90.4 KB

# %%
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 771 entries, 0 to 770
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   COORDINATE         770 non-null    float64
#  1   COUNTRY/PROVINCES  770 non-null    str
#  2   DGUID              770 non-null    str
#  3   GHG EMISSIONS      770 non-null    float64
#  4   SECTOR             770 non-null    str
#  5   UOM                770 non-null    str
#  6   UOM_ID             770 non-null    float64
#  7   VECTOR             770 non-null    str
#  8   Year               770 non-null    float64
# dtypes: float64(4), str(5)
# memory usage: 54.3 KB

# %%
df_clean["Year"].unique()
# Out:
# array([  nan, 2020., 2021., 2023., 2022., 2016., 2017., 2019., 2015.,
#        2013., 2018., 2014.])

# %%
df_clean["COORDINATE"].unique()
# Out:
# array([   nan,  1.1  ,  1.115,  1.118,  1.119,  1.2  ,  2.1  ,  2.115,
#         2.118,  2.119,  2.2  ,  3.1  ,  3.115,  3.118,  3.119,  3.2  ,
#         4.1  ,  4.115,  4.118,  4.119,  4.2  ,  5.1  ,  5.115,  5.118,
#         5.119,  5.2  ,  6.1  ,  6.115,  6.118,  6.119,  6.2  ,  7.1  ,
#         7.115,  7.118,  7.119,  7.2  ,  8.1  ,  8.115,  8.118,  8.119,
#         8.2  ,  9.1  ,  9.115,  9.118,  9.119,  9.2  , 10.1  , 10.115,
#        10.118, 10.119, 10.2  , 11.1  , 11.115, 11.118, 11.119, 11.2  ,
#        12.1  , 12.115, 12.118, 12.119, 12.2  , 13.1  , 13.115, 13.118,
#        13.119, 13.2  , 14.1  , 14.115, 14.118, 14.119, 14.2  ])
